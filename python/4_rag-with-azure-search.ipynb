# %% [markdown]
# # Lab 4: Build a RAG Application with LangChain, Part 3
#
# In this lab we continue to build on [Lab2](./2_rag.ipynb) and [Lab 3](./3_rag-with-chunking.ipynb)
#
# Learning Objectives
#
# * Learn how to use Azure AI Search for a Vector Store
# * Learn how to add citations to the response
#
# ### Step 1: Setup what we covered in Lab 2 and Lab 3
#
# Run the following to get ready for this lesson:

# %%
import os
from dotenv import load_dotenv
from langchain_openai import AzureChatOpenAI
from langchain_openai.embeddings import AzureOpenAIEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate
from langchain_community.document_loaders import DataFrameLoader
from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pandas as pd

load_dotenv()

llm = AzureChatOpenAI(
  openai_api_version="2023-05-15",
  azure_deployment= os.getenv("AZURE_OPENAI_MODEL_DEPLOYMENT_NAME")
)

embeddings = AzureOpenAIEmbeddings()

parser = StrOutputParser()

prompt_template = ChatPromptTemplate.from_messages(
    [
        ("system", """You are a helpful assistant that is very brief but polite in your answers. Answer questions in less than 50 words.
            Answer the question based on the context below. If you can't 
            answer the question, reply "I don't know".

            Context: {context}
         """),
        ("human", "{question}")
    ],
)

DATASET_NAME = "./prep/output/master.json"
transcripts_dataset = pd.read_json(DATASET_NAME)

loader = DataFrameLoader(transcripts_dataset, page_content_column="text")
transcripts = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
documents = text_splitter.split_documents(transcripts)

# %% [markdown]
# See how many documents we are working with in this lab:

# %%
len(documents)
# Out:
# 723

# %% [markdown]
# ### Step 2: Use Azure AI Search as the vector store
#
# **Please change the index name to include your initials or name so it won't have duplicate entries from another user in it**
#
# Run the below to configure the client used to interact with Azure Search

# %%
# !pip3 install azure-storage-blob azure-identity
# Out:
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.19.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-identity
#   Using cached azure_identity-1.16.0-py3-none-any.whl.metadata (76 kB)
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Using cached azure_core-1.30.1-py3-none-any.whl.metadata (37 kB)
# Collecting cryptography>=2.1.4 (from azure-storage-blob)
#   Using cached cryptography-42.0.5-cp39-abi3-macosx_10_12_universal2.whl.metadata (5.3 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting msal>=1.24.0 (from azure-identity)
#   Using cached msal-1.28.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=0.3.0 (from azure-identity)
#   Using cached msal_extensions-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: requests>=2.21.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Collecting cffi>=1.12 (from cryptography>=2.1.4->azure-storage-blob)
#   Using cached cffi-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.24.0->azure-identity)
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: packaging in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from msal-extensions>=0.3.0->azure-identity) (23.2)
# Collecting portalocker<3,>=1.0 (from msal-extensions>=0.3.0->azure-identity)
#   Using cached portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Using cached azure_identity-1.16.0-py3-none-any.whl (166 kB)
# Using cached azure_core-1.30.1-py3-none-any.whl (193 kB)
# Using cached cryptography-42.0.5-cp39-abi3-macosx_10_12_universal2.whl (5.9 MB)
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Using cached msal-1.28.0-py3-none-any.whl (102 kB)
# Using cached msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Using cached cffi-1.16.0-cp312-cp312-macosx_11_0_arm64.whl (177 kB)
# Using cached portalocker-2.8.2-py3-none-any.whl (17 kB)
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: PyJWT, pycparser, portalocker, isodate, cffi, azure-core, cryptography, azure-storage-blob, msal, msal-extensions, azure-identity
# Successfully installed PyJWT-2.8.0 azure-core-1.30.1 azure-identity-1.16.0 azure-storage-blob-12.19.1 cffi-1.16.0 cryptography-42.0.5 isodate-0.6.1 msal-1.28.0 msal-extensions-1.1.0 portalocker-2.8.2 pycparser-2.22

# %%
# !pip3 install azure-search-documents
# Out:
# Collecting azure-search-documents
#   Using cached azure_search_documents-11.4.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-search-documents) (1.30.1)
# Collecting azure-common~=1.1 (from azure-search-documents)
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: isodate>=0.6.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-search-documents) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-search-documents) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-search-documents) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.28.0->azure-search-documents) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-search-documents) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-search-documents) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-search-documents) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rakeshchoudhury/Git/AzureAILab/AzureAI/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-search-documents) (2024.2.2)
# Using cached azure_search_documents-11.4.0-py3-none-any.whl (283 kB)
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Installing collected packages: azure-common, azure-search-documents
# Successfully installed azure-common-1.1.28 azure-search-documents-11.4.0

# %%
from langchain.vectorstores.azuresearch import AzureSearch

vectorstore_address = os.getenv("AZURE_SEARCH_ENDPOINT")
vectorstore_password = os.getenv("AZURE_SEARCH_KEY")

# Add your name to the index name to avoid conflicts with other users
index_name = "bos-gab-index-rakesh"
vectorstore = AzureSearch(
    azure_search_endpoint=vectorstore_address,
    azure_search_key=vectorstore_password,
    index_name=index_name,
    embedding_function=embeddings.embed_query,
)

# %% [markdown]
# Now let's add the documents loaded in Step 1 into the AzureSearch vector store.
#
# > NOTE: This will take a few minutes depending on the network speed.

# %%
vectorstore.add_documents(documents=documents)
# Out:
# ['YjQzOTNiMjMtMDlmYi00MGI0LWEzMDktZmRkN2I0NGM3NjI0',
#  'NTYyOWFjZTktMGI1MC00OTIzLTg1OWYtMzI0OWI2YzY0MTg3',
#  'NThmNjZhMzAtMDgxMS00ZGQ2LTkyYWMtNzJmMzZkZTk3MDFm',
#  'MjE2YWFmZDgtY2I0NS00YjQzLTg3ZDUtMDU5ZTg0Yzg3MTBh',
#  'YmFhNTAwZjktMTQwYS00NjJmLTk1OWUtNmFjNzY0NWFmMDRi',
#  'YjA5ZDAyYmYtNmI4Yy00Y2UxLWE2ZTUtMTZhZmYwZGMyMDU2',
#  'OTk2MGQyNmUtNzM4MC00M2ViLTlhNmYtY2FkOTdiNDZlOGY2',
#  'N2IyNGIyYmMtNmExNi00YmQ4LTgxYTYtOWI4Mzk0ODZlMjVm',
#  'M2I4YWEwZWEtYWM2OS00YzAwLWE4NWMtMWQ4MWNlY2Y5NjBi',
#  'ZTFlMjRkODItODUxMS00MzhkLTgzMmQtZGM4MDNlYWYwZDJl',
#  'NzljY2IzZmUtYTBmMy00ZTNiLTgyNjEtODAwNjA0OTk3NTU1',
#  'MWRhYmZmOGItZDUyZC00YWM5LTk4ZTEtMThhOGNkMzE1NDg3',
#  'OTQyYTU2YWEtYWNhNy00NjkwLWJjZGYtZGZlMmYyN2EyZmZk',
#  'NDRhM2M2YTAtYzgwNS00ZDg5LThmZjYtOWRiNWNjN2Q5ZmJi',
#  'YTAzMmUzMTItM2M5Mi00NzI0LThjNTEtN2M1MzBlZDg4NWY0',
#  'NDE2OTYzODYtMWI0Zi00NThjLTkxMTQtMDc4YjAwOTI1OGE4',
#  'YzlhYWJiOTctMjVhYS00NjQ2LWI3ZjQtODk2MTAyODEzOWFl',
#  'OTk2Y2ZmNDgtMzk0Ny00YmFiLWJkZDktNjYxNWE5YTAzODM3',
#  'MGEzNWRkYjItNDA4Ni00MWVmLWI5NmMtNjNlZDNlYWUyNmQ5',
#  'MzQ0NTY1YTEtNzdlMy00MDBlLTgyMTYtOTY2MGFjZDBiN2E1',
#  'MzNiOTkyZjAtNzY2ZC00ZWQwLWE0YzMtZTUzMzFlNjE5MGNj',
#  'M2M2MDM4NzgtMjM5ZC00YjYxLTlhYjMtYWI2YjYyYjQ5Mzdl',
#  'Nzc0NmMxMTUtZTQ3Ni00OTIyLWJiOWEtNDlkZmI5NmE5MjNk',
#  'OWQzNmY4MDAtNTM0Yi00ZWQyLWExOTEtNzU2ZWY1NjQxZjNm',
#  'ZWRkYzg4ZjQtYjg0OC00MDY5LWI2ZTMtMmE5MjkyM2FhMTk3',
#  'ZGQ4MWY3NmUtNDk3Ni00M2U1LTg1NTYtMTViYTBjNDQ0ZTBh',
#  'NWRlOTczNTAtYzRhMi00NTVmLThlMDYtNTM0MTUyZjIxOGE1',
#  'NzkwMzRkYWItM2NlNy00NmMxLTk0N2UtMzAxODMwZTlkMzgx',
#  'Y2Y4MTdmYjItZGNlOS00NWQzLTk1YTEtODliYTAxYjA2OWM3',
#  'OGI3ZmZiYjQtYzU3OC00NGVjLWIxMGUtOTFmNGIxMjIwYTY5',
#  'NzIzNTE5OTctOGE2Yi00YmQ2LWEyNmMtMDE4ODBhNDU2M2Rj',
#  'NTczNzBjNTUtOTA1NC00MWZlLTg1YTQtYWEyYWJkOGI4OTUw',
#  'Y2Q1OTZhNjMtODg0ZC00YTQ2LTg3ZjUtODE0MjkxZDgyYzg4',
#  'OGYzOTA4OWYtZTEzNC00NDYyLWE2YWEtNDAzYWJlMzQ3NTc1',
#  'MWU3ODlhNmMtZDkyYy00ZmNhLWI5ZWQtMTBmYmMyODQ4NGMx',
#  'ZTgxNWNjMjctNWNmMy00NTg1LWJjNTktMjZlOTJmYjg0NWIx',
#  'N2ZjN2Y2ODAtYTczMC00MjUyLTg0OGQtYzBmMjNhYmMxNWQz',
#  'YjhiNmIwODItMGVlMS00NWE1LWFmZjUtYmE2NzM4ZWJjNzgy',
#  'MDUyYjQyMzEtOGEzNS00YTAwLTgwMDItOWU3ZTI0YTk3MGY0',
#  'NmUzMTA1MzUtOWU3OC00NzQwLTg4NGItNDdkZTJhNTgwNzJh',
#  'YmNhZjNhYzktZjg0YS00NGIzLWI0OGMtMjBlZTQwYjVkNDdi',
#  'MWVkZDllYzQtODdjZi00ODJjLTljNDEtMTIyOTAyY2VhMmZi',
#  'MTlhYjYyYWItNTc1NS00MmVjLTgwOTYtZjc4M2MxMzU3ZjA3',
#  'NzBmOWNiNmEtMzE5YS00ZThkLWE3OTgtZDkzYjA2ZDljYTBl',
#  'YWY0ZTMwMzQtYzgxYi00M2IzLThjNmUtYTUyYWMyM2JhOWQ3',
#  'YjFjOWZmNmMtMWQwZS00NTA5LTkyMjgtNzBlYmE2OWJjZGE0',
#  'NWE1ODEwZTMtMTk0Zi00ODliLWFjNzItMzQ3NzFhNzZjNDg2',
#  'NTY1NGYyZGMtMmQyNy00ZTE1LWJlYzktNjMzM2MyYzEwYjYw',
#  'NGRkZDMwM2EtM2M2OS00ZGVlLWEwNDYtYmQ2YzdkMDcwZjJm',
#  'YzU2M2Y0YTUtZTAyMS00NmYzLTliOGItZjI0ZjE4MGY4MTBh',
#  'ZTJlMDQ3YzItYjM4OS00ZmQzLTg0ZWQtNDkxNmUzNjljNjY4',
#  'YTVmYjViNTUtNzZlOS00NDhjLThiZjUtNzE3ZjExNDc2YmE2',
#  'ZWRiYjk5MWQtM2I5ZS00N2M2LWE5NTEtYzQ0NjRmMzE4MDQ3',
#  'MzI2YmIwM2MtYmUyNi00OGQ1LWIwNzctNTFhMWMyMjNhYWQy',
#  'MTY0YzM0ZmMtYThjMC00Njc3LWI4Y2ItMTM2NjJjYzc4MzI5',
#  'MmMxMmNhYjItNWZmYS00OTA2LWE4OTMtMTM5ZDM4M2Q0MGE4',
#  'M2U3MDNhM2UtOGEwOC00YmE3LWIyZjUtMjJiODg1ODBkNTk0',
#  'NzM1ZjNkNWQtZWVkYi00ODM0LTlhZjAtYjBkMDNmYTM4MTA2',
#  'NGVhMjdkYWYtYzM2Mi00YjNmLWEwMDctNTIzZDIyMDRmY2M2',
#  'YjY3OGQ1NGEtMDZmOS00NWFhLWEyNDYtOWEyYTVlNWMwMDg2',
#  'NjZiNjg2NWUtNDVlNi00NWQwLWIwMTQtNzNhMGYyYTExMDBl',
#  'YjRmNGFiZTktNmQwYS00ODljLWIzZWMtM2JmZjg3NmQ2MDk0',
#  'MzBkOTY4ZWUtMTlmNi00Y2M5LTk0YzMtYTQ0NTE3OWUwZmQ2',
#  'OThjZjRhNWMtZmRlZC00NjNkLWJhMGEtNGJkYzhmNWE5Yzky',
#  'NDM4NzU1NWMtMjM4ZC00YmFhLThmYWItYWJlMDg5ZTQxODAy',
#  'NmZkYzM2N2MtOGM5MC00Yzc0LWE5ZjktZWIyYTliODAxMzM1',
#  'NDM5NjQzM2UtN2FjNy00NmQ1LTkxODEtYmY5YTM5NjE0NmQz',
#  'OTBkMjQxMWQtN2I4Zi00MDQ5LTgxZmMtNjgxZGI4N2JkYmM5',
#  'YmQxMjNhM2UtMDdmMS00ODlkLThkNmUtNGUwOTdkY2JiMWZl',
#  'ZTZhNmNhOWMtMmM0NC00MDhlLThjMmQtNDgyYjIyMmIxN2Jk',
#  'ZjhlYzM3NWEtMDcxOC00MTMzLWFmMTMtZmNhY2YyMzg0ZTQx',
#  'NjQxOWY3NDAtMTM0NS00MWQ3LTllMDItYWMwOGMyZGI1NDNi',
#  'OGRhMzYwNmYtZWU4OC00Nzg0LWIwMTEtMGVmZmY0MDA0ZDNj',
#  'OWNjYTVlYjUtNzJlNy00MWM0LWI3MjUtYzNlNjViYjRjMWI0',
#  'NGNkZjQwMmQtYzAwYi00YTY4LTk5ZWEtZDk2NDNhMmJjMmE1',
#  'ZjVlODhkYmQtYWRiNi00OGRiLWJmYTgtYTAyZWJhOWVlYjYz',
#  'NzlkZWNhNmMtMWVhNy00YjgxLTllNDYtNzU5MmFmYjM4MWM1',
#  'MmY4NzFmZDYtMzEzYi00ZWRmLTlhODMtY2NhYjkzNTYxZjFj',
#  'ZGM2NDZiNDQtY2Q2OS00ZGYxLTk1NGItNzk0MjIxMDVkOTM5',
#  'NTk2NDJlNGEtOGFmNi00MDJhLWIwYWQtOTE1OGQ1MzI0NDM5',
#  'NDJmYjRiYTUtNmRhNy00ZjQ4LWI5YmYtYjQxYWExNTJlYTcz',
#  'MGVkYjEzM2EtYzEzMS00MThhLTkyZGYtNDhmM2RhY2VhMjFl',
#  'OGY2OWY1YmQtOWVkNy00MGY0LTg4ODgtMTdjNTI2MTBhY2Nm',
#  'YmQwNjFiOWUtZTZlNS00NjQyLWI4N2YtNWM2ZWY2MmNiY2Q1',
#  'ZTcwODJkOTItZDI2My00Y2RkLWI1MzgtMWFhNDI5NTk4ODU3',
#  'MGYyYzUyNmUtYzQxNS00MTE1LTkyMGItYzgwNGUzZDViMGQ1',
#  'NjYzZmE1MTctZWU4NC00ODFkLWE4YzUtM2U5ZDVjM2ZkZWIw',
#  'MGZlMmY1N2EtMWU0Zi00MWQ1LWE3YzgtYTkwYTk0NTNiMjBk',
#  'ZTYyZWY2OTctZmY2YS00ZjE2LThjYzgtMTlkMzU1NTFlOGE1',
#  'YzkwOTVlM2YtYjQyMi00OTUyLThjODEtMzc0NWI2YjY1ODg2',
#  'MTViMzc2ZTItMWM2OS00MzdhLWFkY2UtMTQwYmY0MmFhZGIy',
#  'NWNkNWUzNWItMjU4NS00OWVkLWExYjAtMDA2N2I5NDJmMmE4',
#  'OGY1M2RmNmEtZjRhYy00YjczLTg1ZWYtOTg5ZWI5OGQ3NjVl',
#  'MGMzZDFjODUtMDFhZi00MjEyLWFiMzktOGM4NjRjNWI5Mzg3',
#  'NzlkZDRlZDMtNTQwMS00NDQ4LWIwNjEtNDQ1OTA0YTEyZGUx',
#  'OWY2Nzk1NGUtMjlmYS00YTk0LTk0ZmEtNDg2NjE0ZGU5MmJj',
#  'ZjVjZGRhOTctOTUxMS00MzVmLWI0ZWItNjdlOWI4NjkxMjBm',
#  'NTFlMjliMTktNTE0Mi00OWNkLTk0ZGUtYmZmYTAwODQxZTc4',
#  'ODkwMzc5ZDctYmFlOC00YTZiLThkZTEtNmE1NjgxNTZkY2Fm',
#  'MTYzZmExYmEtNDU0My00M2QyLTk1NzQtNzI5ZGIxMzg3ZGUy',
#  'MTUxYmNhMzUtYmJkYi00MjkzLWFhMjktOTRhYWFlNjJlOTQz',
#  'ZjQyMGI3ZjktMmNiNS00ZThkLWIxYjktMjAwNjI2OGU2MGFk',
#  'NjlkNTg5ODYtZjMyYS00OGZhLTk1ZmYtMjJmZjJiMDI0MTc2',
#  'MjM4ODViMzItZThlNS00MTdlLTg0NGMtNDdiZmNiYjFkY2Y5',
#  'ZTFkNDY0MWEtMDhmMS00MDNiLTk4NjgtYWI2Yjk4NTk4MmEy',
#  'MjZmMDc5MzMtZjlkZS00NjNjLWIyYTktZGYxMGFiZGRmM2Ri',
#  'OWIyMzRiNDktM2NkOS00NWZkLWEzOGUtYmI3NmI4YTBiMDUz',
#  'ZjFmNDZmODktYmUyOS00NTUyLTg3NzQtMTZiY2IwZDg5N2E3',
#  'MGFiYzNlZTMtMjFjNi00NjMyLWIxN2QtYTgxNjY5NzM5ZjZi',
#  'ODFhZDFhNzUtMmJjMy00MzU4LWE0MzYtNmY1OGI1NGQ3MWIw',
#  'MmY4YmVlMDQtMTM5MS00MjllLTg0ZmUtYWI3N2M2Y2E4YzQ5',
#  'MGExNTZiZDMtYTQ0Mi00MzgxLTk3MDYtODQ0NDUxMzlmNWJl',
#  'MmI0NjRiZWYtNjJiNS00ZjkwLThiZDEtNzg5Zjc3MWE0NTMy',
#  'YTY3OTc0NmEtZWIzZi00YmE3LWFlZWEtMjc2MGQxYzI0MTU4',
#  'MzUxMjQxNmMtYTk3MC00MDgwLThlMWMtOTRlOWU4YjNlYjRj',
#  'NTBlYTU1MWEtN2M0NC00ZmRhLWI4YmUtMTU2NmUwMjVlY2Q5',
#  'ZTkwMGJjOTEtMDYwYy00NWJhLTk1OGItMzEzM2FjMWIzMDBk',
#  'YTA3MDJlODYtYWM2OS00NGMyLTk0NDctZjgwZDBjNzFlNjhm',
#  'NmZkOGJlNzctN2ZmMy00Y2UwLTljZWQtNzkwNzkyMjUzNmMy',
#  'NTk0NjdkOWMtOGM3ZC00YTJkLThkMjEtYTBmN2UzOGZjMmJj',
#  'ODYyZDA0NGYtZmJjMC00MDFkLTliMDEtMTYyY2EzOTQ3ZjA1',
#  'ZWFmNTBjNTItYTQ0ZS00YTY5LTgyMTgtNDJiMTlhOWEyZGY5',
#  'MmYzMjgzYTMtYmEzNS00MjdhLWI5YTQtZmNiNzYxZGRmZjkz',
#  'MWU4ZjQ1ZGQtNjliOC00NTljLTk0MTAtZTAwMGVlYmFmNWJj',
#  'YzNhNGU5ODgtYTVlMC00NjkxLTg5ZjctOTRjYzhlMjYzNTQw',
#  'NjMxMGQxNDEtZTIyYi00MzQ4LWFhYzItOWRjMzg0NzBlZjY3',
#  'ZGY0M2ExNTYtYzIwYi00MzJiLWE4MDYtMWM0YTVlOWEwZTll',
#  'MDU0ZDlhMGUtMTYxNi00MjNkLWFjNGUtMzc1MjZiYjg4YjQ2',
#  'NmEzNzNjYWItYzljMS00MTZkLWI2YWMtYzQ4MGY2MzUxYTNi',
#  'ZjYzMzc0NDctNDAyYS00YTZjLTgwY2EtODZhYWYzNzcyODk1',
#  'NjNlNjc1MzgtNTNiNS00N2UzLTk0MzYtZjUwNTQwNjgzZDdk',
#  'ZWQ3ZmQ1ZTMtMDRkNy00MTQ5LWFlY2UtMjY3YjIzMjc5ODZj',
#  'OGM1MjhlNmUtNmUwZS00YTM3LTlhZWMtYTRhZmVhNmNmMDRi',
#  'YTYyNjVlNjctNWE1ZC00NjM5LWE4ODQtYThhMjM4ZjVkZTQ4',
#  'OTNmOTFkNWEtYjUxYS00NzhhLThiYmItZjBjNGMwNzhmYzAw',
#  'MWZhY2RkZTQtMzA4Mi00ZWY4LTk1ZTEtNWE0MzM4ZjExMTVk',
#  'ZDQ3NTFiZjQtMDU5YS00NGUxLTk4MmQtMjZkYWYzMWIzNTdj',
#  'YzY1ZDI3OWQtOTM2OS00Y2Q0LThlM2MtYzMyMTgzNTc4ZGQ4',
#  'YWZjMWUzMDYtZjE3MC00NGYzLWJmYzUtZjdjYWJmZWFhN2Q2',
#  'ZTVjNzE1NDUtZTA3Ni00NTJiLWI2OGYtZmU5OWRhODQ1MjUz',
#  'OGY1M2I1Y2QtNzJkYS00ZDU4LTk4NzItODg3YzM3YTZhYzcy',
#  'OWYxYzcyZWEtYjM2OS00NzA1LTgxMzYtZGIwNDZiMDlmODBh',
#  'NDE5ZjQ1NTUtMDBkMS00NWVlLTlkMzgtMjZkYTI2YmQ2Zjc5',
#  'NzIxZTI1YTEtNDViOS00Njg2LTgzYWYtMDNkNWM5MmM0MTk5',
#  'YTMxNTk1ZjAtN2QwOS00NDgxLTkzYzEtNjAyNWViYjk1MDNi',
#  'YTViMTVmOGMtYmRkZi00YmFjLWFmMzQtYWRhZGIzOWU1Yjhk',
#  'NDQzN2YyMmItY2QwYy00ODUxLTkyODAtOGZlODRlYjZlZmY1',
#  'MTY3MmRmNmYtZmViZS00Y2E4LTkyNTktNWFhMjA5OTAzOGU4',
#  'YzMxY2Y0ZGYtZTY2Zi00MmU5LWI5YjktY2RmY2QyNTcwNWNm',
#  'YmRmNWNlNGMtODA1Ny00OWI0LTkyNjMtNzRlZDdkYWI3YTFj',
#  'MDY3OTIxNDktMWZiMi00YWVlLTg2ZWItNzBhZTYzZTAzYmQ2',
#  'NmUyMWI5NjctODVhZS00OGU2LTg3MTYtMjAxNGM3NTYzNzgx',
#  'ODVlYWQ0MTgtNWY1MC00Zjk0LWE2MzktZjUyNDgwYTI0Zjk3',
#  'MDk2ZjA4MWUtZTg5OC00ZWM5LTk1ODEtMTgzMjg0MGViMDBi',
#  'NDkyYjc5YzYtYmQxNi00MTk0LTk0NjgtMjM5OTBmZDM1OTUy',
#  'MmNhYjc4ZmUtYTRmZS00MmM4LTkwMTktM2IxZDE4NTI5ZDhi',
#  'YzI1NDMzZjQtMjU4YS00MTgzLWFhOTktMjQ0YjllYmFmNGEz',
#  'Mjc1YTFhYjgtNTAzNS00NDRiLTg2MmEtY2JmNTEwODgwY2Rm',
#  'NGM5OWYwMzUtOGE3MS00NGU3LWEwMjgtMDIyNjNkYWEzMjRj',
#  'YzYxNTNhZjQtMzcxZS00MDY3LThiMWEtZjk5MjRkMTNlYmJk',
#  'OWFhNGY0YWMtZTMwZC00NjRjLTk4NmUtNWMwYjM5OTU0ZTlk',
#  'NGUxZWVlNjYtNDI5Yi00OWJkLWE0ODAtZTVhMjRiNTNmMTM5',
#  'ZGZiYzc2YzYtYzA0ZC00YWFlLWFmYjYtMWY3MjFlYTE2NTUw',
#  'MTA1Yjc5Y2MtMDQ2NS00YzQ1LTljNDItOWQ1NDFlOTEzNjAx',
#  'ZDBmY2NkMTYtMWNkMC00ZmJlLTg0NzUtOGFkMzI0ZGQ2YjFm',
#  'NGJkODg4ZTUtOTYzMy00ZWFlLWE1ZTgtMGYxMzc3M2ZmMjYx',
#  'MTkyODdjOTItMTllYi00ZDZkLTgyYzEtOGNmNWRmMGU5MDBj',
#  'NGI5ZTk5NDgtZmFlNS00MDYzLThiMzMtMTRkNjc2MTgwMDMy',
#  'ZjBmOTMwMzgtNTQ3Ny00MTk1LWFhZjYtMmUxMWU0ZTYyYTM4',
#  'M2FjMjFhZjYtNzk4ZS00ZDJlLWI2YjQtODliYzJjMGE0NzJh',
#  'ZGZmZWYxNDMtYjMzZS00ZTE2LTllZjQtZjQ3MjcxN2RkYjk1',
#  'NTcwNDc0N2MtNzU4YS00OTNlLWI1Y2QtOTg5YWU1ZWI0ZDIw',
#  'YjY1Yzk4NGQtY2IxOS00ODExLWE0YjQtZDMzMTJlMzgzM2M5',
#  'Mjc5YTIwMjYtODQzNC00MjAzLWI2ZjAtOTZhZDU4NTVlMDYy']

# %% [markdown]
# Now there are documents to use, try a similarity search to verify things are working:

# %%
docs = vectorstore.similarity_search(
    query="What is langchain?",
    k=3,
    search_type="similarity",
)
docs
# Out:
# [Document(page_content="show that so you know there's the general architecture of the code and uh now our code is using you know python for the back end and it's just using the open AI SDK with the Azure you know document search SDK it's not using any fancy llm orchestration libraries and people always ask like why aren't you using Lang chain why aren't you using this why aren't you using that well part of the reason I'm not using any of those is because everybody has a different favorite library for Python and I'd have to pick one of them and I and then that would like alienate other people right so there are many popular rag orchestration libraries and you could totally use those as well you know whichever one works for you uh so the most popular ones in the open source world are Lang chain and llama index and both of them are available in multiple languages and then from Microsoft we've got Mantic kernel which is probably the most similar to linkchain and which is that's in Python and oh I should have", metadata={'speaker': '', 'title': 'Pamela Fox: Building a RAG app to chat with your data', 'videoId': '3Zh9MEuyTQo', 'description': "This is a recording of the March 28, 2024 meeting.One of the most popular use cases for generative AI is RAG (Retrieval-Augmented-Generation), a technique that feeds context to an LLM (large language model) so that it can answer questions according to sources. Thousands of developers have deployed RAG applications to chat with their data, both for internal enterprise data (like HR or support) and external public data (like government or retail). In this talk, I'll show how to build a RAG with Azure technology, like Azure AI search and Azure OpenAI, and share best practices for data ingestion, orchestration, and evaluation.Pamela FoxPamela Fox is a Cloud Advocate in Python at Microsoft. Previously, she was a lecturer for UC Berkeley and the creator of the computer programming curriculum for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure"}),
#  Document(page_content="at the code it will make a lot of sense so what is golang or i should say go not golang so it's an open source programming language it was it was found in 2009 i think i should know but i believe it's 2009 and let me give you guys a full screen version because you guys have been seeing the non-full screen version um so it was built by the the founders of the the c language and b language as well and the founders of of the language want this to be a super simple uh you know no nonsense slim language that just works because they were working a lot with the existing languages for the back end and they realized that they needed something better so it's funded by it's backed by google the team that built it and is working on it is is in google is google team as well so what's the idea behind it well it's a journal per general purpose language so it can be used to build all sorts of applications it's it is compiled into your native code so when we compile it on windows where i mean x86 arm", metadata={'speaker': '', 'title': 'Deploy Your GO API to Azure Functions', 'videoId': '1NcnkU403UE', 'description': 'This is a recording of the September 8, 2022 meeting.Do you want to build backend application but don’t like JavaScript? Let’s GO. GO is an open-source programming language with simplicity at its core. It is supported by Google is widely in use for backend and CLI applications with a growing ecosystem of communities, partners, and tools. It is easy to get started with GO and build amazing applications.Ok, so now you built your GO API and want to publish to Azure. In this session, we will take a tour of GO lang and explore a REST API built with GO and hosted it in Azure as Azure Function.About the speakerHussain Abbasi is the Head of Technology at ChaiOne. He is a content-creator, blogger, speaker, streamer, and software engineer with over a decade of experience developing mobile, web, cloud, and desktop applications.Hussain is a well-known community leader in the mobile development space. He is a co-organizer of Houston Xamarin User Group and the organizer for Houston Flutter User Group in Houston area and authors and contributes to several OSS projects.You can find his shenanigans at hussainabbasi.com. Or his blog at intelliAbb.com. You can find him on Twitter @HussainNAbbasi.'}),
#  Document(page_content="for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure. Json the data format thank you Jason for the introduction uh I do have the slides available for those who want to have a copy of the slides or follow along with them you should be able to get them from that speaker deck link so today we're going to talk about large language models briefly just to you know set the stage um for that terminology then go deep into rag which is retrieval augmented generation uh go and look at this open source rag chat app solution that can be deployed on as your talk about how to evaluate rag chat applications and talk about observability for rag chat applications on Azure so just to start off with talking about llms uh so llm stands for large language model it is a model that's so large that it achieves general purpose language understanding and generation so example I like to", metadata={'speaker': '', 'title': 'Pamela Fox: Building a RAG app to chat with your data', 'videoId': '3Zh9MEuyTQo', 'description': "This is a recording of the March 28, 2024 meeting.One of the most popular use cases for generative AI is RAG (Retrieval-Augmented-Generation), a technique that feeds context to an LLM (large language model) so that it can answer questions according to sources. Thousands of developers have deployed RAG applications to chat with their data, both for internal enterprise data (like HR or support) and external public data (like government or retail). In this talk, I'll show how to build a RAG with Azure technology, like Azure AI search and Azure OpenAI, and share best practices for data ingestion, orchestration, and evaluation.Pamela FoxPamela Fox is a Cloud Advocate in Python at Microsoft. Previously, she was a lecturer for UC Berkeley and the creator of the computer programming curriculum for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure"})]

# %% [markdown]
# Ok, it seems to be working. Now let's move toward the functionality we testing in Lab 3.
#
# Create a retriever to use later:

# %%
retriever = vectorstore.as_retriever()

# %% [markdown]
# Test to see if it is working:

# %%
unique_docs = retriever.get_relevant_documents(query="What is langchain?")
unique_docs
# Out:
# [Document(page_content="at the code it will make a lot of sense so what is golang or i should say go not golang so it's an open source programming language it was it was found in 2009 i think i should know but i believe it's 2009 and let me give you guys a full screen version because you guys have been seeing the non-full screen version um so it was built by the the founders of the the c language and b language as well and the founders of of the language want this to be a super simple uh you know no nonsense slim language that just works because they were working a lot with the existing languages for the back end and they realized that they needed something better so it's funded by it's backed by google the team that built it and is working on it is is in google is google team as well so what's the idea behind it well it's a journal per general purpose language so it can be used to build all sorts of applications it's it is compiled into your native code so when we compile it on windows where i mean x86 arm", metadata={'speaker': '', 'title': 'Deploy Your GO API to Azure Functions', 'videoId': '1NcnkU403UE', 'description': 'This is a recording of the September 8, 2022 meeting.Do you want to build backend application but don’t like JavaScript? Let’s GO. GO is an open-source programming language with simplicity at its core. It is supported by Google is widely in use for backend and CLI applications with a growing ecosystem of communities, partners, and tools. It is easy to get started with GO and build amazing applications.Ok, so now you built your GO API and want to publish to Azure. In this session, we will take a tour of GO lang and explore a REST API built with GO and hosted it in Azure as Azure Function.About the speakerHussain Abbasi is the Head of Technology at ChaiOne. He is a content-creator, blogger, speaker, streamer, and software engineer with over a decade of experience developing mobile, web, cloud, and desktop applications.Hussain is a well-known community leader in the mobile development space. He is a co-organizer of Houston Xamarin User Group and the organizer for Houston Flutter User Group in Houston area and authors and contributes to several OSS projects.You can find his shenanigans at hussainabbasi.com. Or his blog at intelliAbb.com. You can find him on Twitter @HussainNAbbasi.'}),
#  Document(page_content="which is probably the most similar to linkchain and which is that's in Python and oh I should have said net that's really what it is is net we we'll fix that python and.net I don't think it's in typescript um I obviously haven't used it very much at all and then there's also Microsoft prompt flow and that's built into a your AI studio so it works really well if you're using as your AI studio and doing other machine learning model stuff so you can totally use these libraries uh you know I tend to not use any libraries because I like to work really you know really close to the metal H because things are changing all the time and I want to be able to take advantage of everything uh but these libraries do have a lot of advantages as well because they have like documented you know ways of doing things right so llama index for example it actually has a way of indexing into postgress and doing a hybrid search uh just already built in there so they've already got that that built in so", metadata={'speaker': '', 'title': 'Pamela Fox: Building a RAG app to chat with your data', 'videoId': '3Zh9MEuyTQo', 'description': "This is a recording of the March 28, 2024 meeting.One of the most popular use cases for generative AI is RAG (Retrieval-Augmented-Generation), a technique that feeds context to an LLM (large language model) so that it can answer questions according to sources. Thousands of developers have deployed RAG applications to chat with their data, both for internal enterprise data (like HR or support) and external public data (like government or retail). In this talk, I'll show how to build a RAG with Azure technology, like Azure AI search and Azure OpenAI, and share best practices for data ingestion, orchestration, and evaluation.Pamela FoxPamela Fox is a Cloud Advocate in Python at Microsoft. Previously, she was a lecturer for UC Berkeley and the creator of the computer programming curriculum for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure"}),
#  Document(page_content="show that so you know there's the general architecture of the code and uh now our code is using you know python for the back end and it's just using the open AI SDK with the Azure you know document search SDK it's not using any fancy llm orchestration libraries and people always ask like why aren't you using Lang chain why aren't you using this why aren't you using that well part of the reason I'm not using any of those is because everybody has a different favorite library for Python and I'd have to pick one of them and I and then that would like alienate other people right so there are many popular rag orchestration libraries and you could totally use those as well you know whichever one works for you uh so the most popular ones in the open source world are Lang chain and llama index and both of them are available in multiple languages and then from Microsoft we've got Mantic kernel which is probably the most similar to linkchain and which is that's in Python and oh I should have", metadata={'speaker': '', 'title': 'Pamela Fox: Building a RAG app to chat with your data', 'videoId': '3Zh9MEuyTQo', 'description': "This is a recording of the March 28, 2024 meeting.One of the most popular use cases for generative AI is RAG (Retrieval-Augmented-Generation), a technique that feeds context to an LLM (large language model) so that it can answer questions according to sources. Thousands of developers have deployed RAG applications to chat with their data, both for internal enterprise data (like HR or support) and external public data (like government or retail). In this talk, I'll show how to build a RAG with Azure technology, like Azure AI search and Azure OpenAI, and share best practices for data ingestion, orchestration, and evaluation.Pamela FoxPamela Fox is a Cloud Advocate in Python at Microsoft. Previously, she was a lecturer for UC Berkeley and the creator of the computer programming curriculum for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure"}),
#  Document(page_content="for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure. Json the data format thank you Jason for the introduction uh I do have the slides available for those who want to have a copy of the slides or follow along with them you should be able to get them from that speaker deck link so today we're going to talk about large language models briefly just to you know set the stage um for that terminology then go deep into rag which is retrieval augmented generation uh go and look at this open source rag chat app solution that can be deployed on as your talk about how to evaluate rag chat applications and talk about observability for rag chat applications on Azure so just to start off with talking about llms uh so llm stands for large language model it is a model that's so large that it achieves general purpose language understanding and generation so example I like to", metadata={'speaker': '', 'title': 'Pamela Fox: Building a RAG app to chat with your data', 'videoId': '3Zh9MEuyTQo', 'description': "This is a recording of the March 28, 2024 meeting.One of the most popular use cases for generative AI is RAG (Retrieval-Augmented-Generation), a technique that feeds context to an LLM (large language model) so that it can answer questions according to sources. Thousands of developers have deployed RAG applications to chat with their data, both for internal enterprise data (like HR or support) and external public data (like government or retail). In this talk, I'll show how to build a RAG with Azure technology, like Azure AI search and Azure OpenAI, and share best practices for data ingestion, orchestration, and evaluation.Pamela FoxPamela Fox is a Cloud Advocate in Python at Microsoft. Previously, she was a lecturer for UC Berkeley and the creator of the computer programming curriculum for Khan Academy. She has founded GDI chapters globally and develops curriculum for GDI.Slides: https://speakerdeck.com/pamelafox/building-a-rag-app-to-chat-with-your-data-on-azure"})]

# %% [markdown]
# Now just like at the end of Lab 3, try out it out - just remember the vector store is not running in-memory this time, but in Azure.

# %%
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt_template
    | llm
    | parser
)

chain.invoke("What is LangChain?")
# Out:
# "LangChain is a popular orchestration library used for generative AI applications, including RAG (Retrieval-Augmented-Generation). It's available in multiple languages and is commonly used in the open-source world."

# %% [markdown]
# ### Step 3: Add citations for identifying the source
#
# One of the important parts of a RAG application is to include citations - this helps verify the LLM is not making something up.
#
# > NOTE: Citations do not guarantee the LLM didn't make up the response, but it does help to verify to help you with a confidence level.
#
# In order to have the response include citations we need to do a couple of things:
# 1. Modify the document listing used as the context to include the title of the video
# 1. Modify the prompt with some instructions for how to use the title and how we want it returned
#
# The first thing we need is a utility function we'll use to modify the string returned from the retriever so the format will look like:
# ```code
# "<video title>:<transcript text>"
# ```
#
# Run the following to declare the utility function:

# %%
def format_docs(docs):
    return "\n\n".join([f"{d.metadata['title']}:{d.page_content}" for d in docs])

# %% [markdown]
# Next, we need to modify the prompt template to let the LLM know how the context is formatted and how to use the title and content:

# %%
prompt_template_with_citations = ChatPromptTemplate.from_messages(
    [
        ("system", """Assistant helps people with their questions about the content of video transcripts. Be brief in your answers.
        Answer ONLY with the facts listed in the list of sources below. If there isn't enough information below, say you don't know. 
        Do not generate answers that don't use the sources below. If asking a clarifying question to the user would help, ask the question.
        Each source has a title followed by colon and the actual information, always include the source title for each fact you use in the response. 
         Use square brackets to reference the source, for example [Video title here]. Don't combine sources, list each source separately, for example [Video 1][Video 2].
            Context: {context}
         """),
        ("human", "{question}")
    ],
)

chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt_template_with_citations
    | llm
    | parser
)

# %% [markdown]
# Now give it a try:

# %%
chain.invoke("What is langchain?")
# Out:
# '[Building a RAG app to chat with your data] Langchain is an open-source rag orchestration library available in multiple languages, including Python. It is one of the popular libraries for building RAG applications.'

# %%
chain.invoke("What is AKS?")
# Out:
# 'Azure Kubernetes Service (AKS) is a managed Kubernetes service offered by Microsoft that simplifies the deployment of a managed Kubernetes cluster in Azure by offloading the operational overhead to Azure. It allows users to manage their AKS environment in Azure and run Kubernetes workloads, including quick demos. Vaibhav Gujral covers AKS in a deep dive session in the recording. [Running Kubernetes in Azure using AKS]'

# %% [markdown]
# ### References
#
# Here are some good resources to learn more about using Azure AI Search with LangChain:
# * [Azure Cognitive Search and LangChain: A Seamless Integration for Enhanced Vector Search Capabilities](https://techcommunity.microsoft.com/t5/ai-azure-ai-services-blog/azure-cognitive-search-and-langchain-a-seamless-integration-for/ba-p/3901448)
# * LangChain Docs [Azure AI Search](https://python.langchain.com/docs/integrations/vectorstores/azuresearch/)
# * [Azure AI Search client library for Python - version 11.4.0](https://learn.microsoft.com/en-us/python/api/overview/azure/search-documents-readme?view=azure-python)
#
# ## [Go To Next Lab](./5_rag-final.ipynb.ipynb)
